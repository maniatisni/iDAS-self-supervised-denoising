# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from utils import *
from glob import glob

# %%
train_path = "train"
test_path = "test"
train_path_raw = "train-full"
test_path_raw = "test-full"
train_files = glob(os.path.join(train_path, '*.npy'))
train_files_raw = glob(os.path.join(train_path_raw, '*.npy'))
test_files = glob(os.path.join(test_path, '*.npy'))
test_files_raw = glob(os.path.join(test_path_raw, '*.npy'))

# %% [markdown]
# ## Test file - raw data

# %%
x = np.load(train_files_raw[0])

# %%
plt.figure(dpi=120)
plt.imshow(x, aspect='auto',cmap='seismic',interpolation='None')
plt.colorbar()

# %%
plt.plot(x[1700])

# %% [markdown]
# ## Test file, after:
# - selecting 600 of the 5568 channels
# - downsampling
# - applying a 1-10 Hz filter
# - normalizing (division with std. dev)

# %%
y = np.load(train_files[0])
plt.figure(dpi=120)
plt.imshow(y, aspect='auto',cmap='seismic',interpolation='None')
plt.colorbar()

# %%
plt.plot(y[0])

# %% [markdown]
# ## Do the same with test files
# #### Before:

# %%
x_ = np.load(test_files_raw[1])
plt.figure(dpi=120)
plt.imshow(x_, aspect='auto',cmap='seismic',interpolation='None')
plt.colorbar()

# %%
plt.plot(x_[1700])

# %% [markdown]
# #### After:

# %%
y_ = np.load(test_files[2])
plt.figure(dpi=120)
plt.imshow(y_, aspect='auto',cmap='seismic',interpolation='None')
plt.colorbar()

# %%
plt.plot(y_[0])
