# %%
from dataloaders import DAS_data_generator
from torch.utils.data import DataLoader
from model import DenoisingUNet
from glob import glob
from utils import *
import os
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# ## Train & Validation sets

# %%
train_path = "../data/HCMR-Nestor/train"
val_path = "../data/HCMR-Nestor/val"
train_files = glob(os.path.join(train_path, '*.npy'))
val_files = glob(os.path.join(val_path, '*.npy'))

# %%
print(f"{len(train_files)} train and {len(val_files)} val files.")
# Out:
# 23 train and 6 val files.

# %%
train_samples = []
for file in train_files:
    data = np.load(file)
    N_t = data.shape[1]
    t_slice = slice(N_t//4, 3*N_t//4)
    scaled_data = np.zeros_like(data)
    # Loop over data and normalise
    for i, wv in enumerate(data):
        scaled_data[i] = wv / wv[t_slice].std()
    train_samples.append(scaled_data)
train_samples = np.stack(train_samples)

# %%
val_samples = []
for file in val_files:
    data = np.load(file)
    N_t = data.shape[1]
    t_slice = slice(N_t//4, 3*N_t//4)
    scaled_data = np.zeros_like(data)
    # Loop over data and normalise
    for i, wv in enumerate(data):
        scaled_data[i] = wv / wv[t_slice].std()
    val_samples.append(scaled_data)
val_samples = np.stack(val_samples)

# %% [markdown]
# ## Hyperparameters

# %%
N_sub = 11
hidden_layers = 4
learning_rate = 0.0002
num_epochs = 50
Nt = 2048
train_batch_size = 32
val_batch_size = 32
train_batch_multiplier = 10
val_batch_multiplier = 10

# %% [markdown]
# ## Datasets and DataLoaders

# %%
train_dataset = DAS_data_generator(train_samples, N_sub=N_sub, batch_size=train_batch_size, batch_multiplier=train_batch_multiplier)
train_loader = DataLoader(train_dataset, batch_size=1, drop_last=True, shuffle=True)

# %%
val_dataset = DAS_data_generator(val_samples, N_sub=N_sub, batch_size=val_batch_size, batch_multiplier=val_batch_multiplier)
val_loader = DataLoader(val_dataset, batch_size=1, drop_last=True, shuffle=True)

# %%
for (samples, masks), masked_samples in train_loader:
    samples = samples[0]
    masks = masks[0]
    masked_samples = masked_samples[0]
    break
# Draw canvas
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(9, 4))

# Show sample (without blanking)
axes[0].imshow(samples[0, :, :], aspect="auto", vmin=-1, vmax=1, origin="upper")
axes[0].axis("off")

# Show mask
axes[1].imshow(masks[0, :, :], aspect="auto", vmin=-1, vmax=1, origin="upper")
axes[1].axis("off")

# Show prediction target
axes[2].imshow(masked_samples[0, :, :], aspect="auto", vmin=-1, vmax=1, origin="upper")
axes[2].axis("off")

plt.tight_layout()
plt.show()

# %%
# GPU
print(torch.cuda.get_device_name(0))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'device is {device}.')

# Load model trained at synthetic data
model = DenoisingUNet(input_bands=1, output_classes=1, hidden_channels=hidden_layers)
state = torch.load('models/pretrained_synthetic.pth')
model.load_state_dict(state['model_state_dict'])
model.train()
model.to(device)
# Mean Square Error 
criterion = nn.MSELoss()

# Optimizer:
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# NVIDIA GeForce RTX 2070
# device is cuda:0.

# %% [markdown]
# ## Training

# %%
epochs_losses_train = []
epochs_losses_val = []
for epoch in range(num_epochs):
    train_loader.dataset.__init__(train_samples, N_sub=N_sub, batch_size=train_batch_size, batch_multiplier=train_batch_multiplier)
    batch_losses = []
    ## TRAIN ##
    model.train()
    for (samples, masks), masked_samples in train_loader:
        samples = samples[0].reshape(train_batch_size,1,N_sub,Nt).float().to(device)
        masks = masks[0].reshape(train_batch_size,1,N_sub,Nt).float().to(device)
        masked_samples = masked_samples[0].reshape(train_batch_size,1,N_sub,Nt).float().to(device)
        # apply mask
        sample = (samples * masks).clone().detach()
        optimizer.zero_grad()
        c_mask = 1-masks
        # apply complementary mask to output (proj. operator)
        output = model(sample)*c_mask
        loss = criterion(output, masked_samples)
        batch_losses.append(loss.item())
        loss.backward()
        optimizer.step()
    epochs_losses_train.append(np.mean(batch_losses))
    model.eval()
    eval_losses = []
    with torch.no_grad():
        val_loader.dataset.__init__(val_samples, N_sub=N_sub, batch_size=val_batch_size, batch_multiplier=val_batch_multiplier)
        for (samples, masks), masked_samples in val_loader:
            samples = samples[0].reshape(val_batch_size,1,N_sub,Nt).float().to(device)
            masks = masks[0].reshape(val_batch_size,1,N_sub,Nt).float().to(device)
            masked_samples = masked_samples[0].reshape(val_batch_size,1,N_sub,Nt).float().to(device)
            # apply mask
            sample = samples * masks.clone().detach()
            optimizer.zero_grad()
            c_mask = 1-masks
            # apply complementary mask to output (proj. operator)
            output = model(sample)*c_mask
            loss = criterion(output, masked_samples)
            eval_losses.append(loss.item())
        epochs_losses_val.append(np.mean(eval_losses))
    print(f"Epoch: {epoch} Training Loss: {epochs_losses_train[-1]}, Validation Loss: {epochs_losses_val[-1]}")
# Out:
# Epoch: 0 Training Loss: 0.028755686926129072, Validation Loss: 0.060085233363012476
# Epoch: 1 Training Loss: 0.02842577984151633, Validation Loss: 0.05858011425783237
# Epoch: 2 Training Loss: 0.028168800011601138, Validation Loss: 0.05683321294685205
# Epoch: 3 Training Loss: 0.027837645967045556, Validation Loss: 0.054554588596026105
# Epoch: 4 Training Loss: 0.02766543209714734, Validation Loss: 0.056134072070320444
# Epoch: 5 Training Loss: 0.027363566770825697, Validation Loss: 0.05568009897445639
# Epoch: 6 Training Loss: 0.027185082783841567, Validation Loss: 0.05339869754388928
# Epoch: 7 Training Loss: 0.027141994108324467, Validation Loss: 0.054430553161849575
# Epoch: 8 Training Loss: 0.02726401896418437, Validation Loss: 0.05305685332665841
# Epoch: 9 Training Loss: 0.02757664356056763, Validation Loss: 0.05292274970561266
# Epoch: 10 Training Loss: 0.026974029401722163, Validation Loss: 0.05336425537243485
# Epoch: 11 Training Loss: 0.026880105625352133, Validation Loss: 0.05496080806478858
# Epoch: 12 Training Loss: 0.026665719525645608, Validation Loss: 0.05387955099965135
# Epoch: 13 Training Loss: 0.02687393091619015, Validation Loss: 0.053422789182513954
# Epoch: 14 Training Loss: 0.02661196136766154, Validation Loss: 0.05373685198525588
# Epoch: 15 Training Loss: 0.026638788397869338, Validation Loss: 0.05428371240074436
# Epoch: 16 Training Loss: 0.026855991667379505, Validation Loss: 0.051859031120936074
# Epoch: 17 Training Loss: 0.026486636058467884, Validation Loss: 0.05029867213840286
# Epoch: 18 Training Loss: 0.02669940317940453, Validation Loss: 0.05216205731655161
# Epoch: 19 Training Loss: 0.026765103589581406, Validation Loss: 0.05176531402394176
# Epoch: 20 Training Loss: 0.026639965063203937, Validation Loss: 0.04955382626503706
# Epoch: 21 Training Loss: 0.026458236526535905, Validation Loss: 0.04908946383123596
# Epoch: 22 Training Loss: 0.02665293692894604, Validation Loss: 0.049792733912666635
# Epoch: 23 Training Loss: 0.027114996718971624, Validation Loss: 0.05194760290905833
# Epoch: 24 Training Loss: 0.026573958037340122, Validation Loss: 0.051165586337447166
# Epoch: 25 Training Loss: 0.02665795219819183, Validation Loss: 0.04934240054960052
# Epoch: 26 Training Loss: 0.026375948022241177, Validation Loss: 0.04835870200768113
# Epoch: 27 Training Loss: 0.02641683596631755, Validation Loss: 0.05139517957965533
# Epoch: 28 Training Loss: 0.026463170479173247, Validation Loss: 0.04943052552019556
# Epoch: 29 Training Loss: 0.026895665919975095, Validation Loss: 0.048340238723903896
# Epoch: 30 Training Loss: 0.026451703590219436, Validation Loss: 0.050763049411276975
# Epoch: 31 Training Loss: 0.026524965100638245, Validation Loss: 0.05010525214796265
# Epoch: 32 Training Loss: 0.026289774177838926, Validation Loss: 0.048352650149414936
# Epoch: 33 Training Loss: 0.026305565440460393, Validation Loss: 0.04987299029404919
# Epoch: 34 Training Loss: 0.026412490075049193, Validation Loss: 0.05184839532400171
# Epoch: 35 Training Loss: 0.026728577126303443, Validation Loss: 0.050431566685438155
# Epoch: 36 Training Loss: 0.02638791871621557, Validation Loss: 0.049345715219775835
# Epoch: 37 Training Loss: 0.02624564666462981, Validation Loss: 0.05036009000614285
# Epoch: 38 Training Loss: 0.026401728658896426, Validation Loss: 0.050577876064926384
# Epoch: 39 Training Loss: 0.026334015199023744, Validation Loss: 0.05078951455652714
# Epoch: 40 Training Loss: 0.026603325221525587, Validation Loss: 0.05019059246405959
# Epoch: 41 Training Loss: 0.026158225074734375, Validation Loss: 0.05172366245339314
# Epoch: 42 Training Loss: 0.02644470937388099, Validation Loss: 0.05012114156658451
# Epoch: 43 Training Loss: 0.026289761738608714, Validation Loss: 0.04953329221655925
# Epoch: 44 Training Loss: 0.026323499530553816, Validation Loss: 0.05093669472262263
# Epoch: 45 Training Loss: 0.02635992026847342, Validation Loss: 0.05079749875391523
# Epoch: 46 Training Loss: 0.02630670091704182, Validation Loss: 0.050634735419104494
# Epoch: 47 Training Loss: 0.02648477920371553, Validation Loss: 0.05115635783101122
# Epoch: 48 Training Loss: 0.026239115639549233, Validation Loss: 0.05199754983186722
# Epoch: 49 Training Loss: 0.0264858393403499, Validation Loss: 0.04903990530098478

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))
ax1.plot(epochs_losses_train)
ax1.set_title("Train MSE")
ax2.plot(epochs_losses_val, 'orange')
ax2.set_title("Validation MSE")
# Out:
# Text(0.5, 1.0, 'Validation MSE')

# %%
# save model
torch.save({
    'epoch': epoch,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'loss': loss
}, "models/pretrained_DAS.pth")
